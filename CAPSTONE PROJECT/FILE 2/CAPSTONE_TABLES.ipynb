# %%
#Importing necessary libraries-
import selenium
import pandas as pd
import time
import requests

# %% [markdown]
# FINAL DATA

# %%
M1=pd.read_csv('Manyavar_M1.csv')

# %%
M1
# Out:
#      Unnamed: 0                 Brand Category  Product_type  \
# 0             0  Vedant Fashions Ltd.      Men  Kurta Pajama
# 1             1  Vedant Fashions Ltd.      Men  Kurta Pajama
# 2             2  Vedant Fashions Ltd.      Men  Kurta Pajama
# 3             3  Vedant Fashions Ltd.      Men  Kurta Pajama
# 4             4  Vedant Fashions Ltd.      Men  Kurta Pajama
# ..          ...                   ...      ...           ...
# 145         145  Vedant Fashions Ltd.      Men  Kurta Pajama
# 146         146  Vedant Fashions Ltd.      Men  Kurta Pajama
# 147         147  Vedant Fashions Ltd.      Men  Kurta Pajama
# 148         148  Vedant Fashions Ltd.      Men  Kurta Pajama
# 149         149  Vedant Fashions Ltd.      Men  Kurta Pajama
#
#                                           Product_Name    Product_code  \
# 0                        Rust Orange Printed Kurta Set     SOSK630-332
# 1       Flamingo Pink Chikankari Embroidered Kurta Set     SDES820-325
# ...

# %%
M2=pd.read_csv('Manyavar_M2.csv')

# %%
M2
# Out:
#      Unnamed: 0     Wear_type Material_type  \
# 0             0  Kurta Pajama      --------
# 1             1  Kurta Pajama      --------
# 2             2  Kurta Pajama           NaN
# 3             3  Kurta Pajama           NaN
# 4             4  Kurta Pajama           NaN
# ..          ...           ...           ...
# 145         145  Kurta Pajama           NaN
# 146         146  Kurta Pajama           NaN
# 147         147  Kurta Pajama           NaN
# 148         148  Kurta Pajama      --------
# 149         149  Kurta Pajama      --------
#
#                                          Reviews    color1    color2
# 0    674 people have viewed the product recently  --------  --------
# 1    674 people have viewed the product recently  --------       NaN
# 2    674 people have viewed the product recently       NaN       NaN
# 3                                       --------       NaN       NaN
# 4    674 people have viewed the product recently       NaN  --------
# ...

# %%
M3=pd.read_csv('Manyavar_M3.csv')

# %%
M3
# Out:
#      Unnamed: 0 Country_of_origin  Return_time Size1 Size2 Size3 Size4  \
# 0             0             India         15.0     S     M     L    XL
# 1             1             India         15.0     S     M     L    XL
# 2             2             India         15.0     S     M     L    XL
# 3             3          --------          NaN     S     M     L    XL
# 4             4             India         15.0     S     M     L    XL
# ..          ...               ...          ...   ...   ...   ...   ...
# 145         145             India         15.0     S     M     L    XL
# 146         146             India         15.0     S     M     L    XL
# 147         147             India         15.0     S     M     L    XL
# 148         148          --------          NaN     S     M     L    XL
# 149         149          --------          NaN     S     M     L    XL
#
#         Occassion
# 0    Indo Western
# 1    Indo Western
# 2    Indo Western
# 3    Indo Western
# ...

# %%
W1=pd.read_csv('Biba_W1.csv')

# %%
W1
# Out:
#      Unnamed: 0  Sno Brand Category Product_type  \
# 0             0    0  BIBA    Women        Kurta
# 1             1    1  BIBA    Women        Kurta
# 2             2    2  BIBA    Women        Kurta
# 3             3    3  BIBA    Women        Kurta
# 4             4    4  BIBA    Women        Kurta
# ..          ...  ...   ...      ...          ...
# 295         295  195  BIBA    Women        Kurta
# 296         296  196  BIBA    Women        Kurta
# 297         297  197  BIBA    Women        Kurta
# 298         298  198  BIBA    Women        Kurta
# 299         299  199  BIBA    Women        Kurta
#
#                                           Product_Name  \
# 0                   LILAC POLYESTER STRAIGHT KURTA SET
# 1                       BLACK RAYON STRAIGHT KURTA SET
# 2                   WHITE PINK RAYON GATHERED SUIT SET
# 3                    PEACH POLYESTER GATHERED SUIT SET
# 4              POWDER BLUE POLYESTER STRAIGHT SUIT SET
# ...

# %%
W2=pd.read_csv('Biba_W2.csv')

# %%
W2
# Out:
#      Unnamed: 0  Sno                Wear_type Material_type  \
# 0             0    0     Kurta, Pant, Dupatta           NaN
# 1             1    1    Kurta, Palazzo, Stole      --------
# 2             2    2  Kurta, Palazzo, Dupatta      --------
# 3             3    3     Kurta, Pant, Dupatta           NaN
# 4             4    4     Kurta, Pant, Dupatta           NaN
# ..          ...  ...                      ...           ...
# 295         295  195           Kurta, Palazzo           NaN
# 296         296  196           Kurta, Palazzo           NaN
# 297         297  197    Kurta, Inner, Palazzo           NaN
# 298         298  198                      NaN           NaN
# 299         299  199           Kurta, Palazzo           NaN
#
#                                                Reviews       color1  \
# 0    When it comes to ethnic wear for women, the on...    Brick Red
# 1    When it comes to ethnic wear for women, the on...   Blush Pink
# ...

# %%
W3=pd.read_csv('Biba_W3.csv')

# %%
W3
# Out:
#      Unnamed: 0  Sno Country_of_origin  Return_time  Size1  Size2  Size3  \
# 0             0    0               NaN           15     32     34     36
# 1             1    1               NaN           15     32     34     36
# 2             2    2               NaN           15     32     34     36
# 3             3    3               NaN           15     32     34     36
# 4             4    4               NaN           15     32     34     36
# ..          ...  ...               ...          ...    ...    ...    ...
# 295         295  195             India           15     32     34     36
# 296         296  196             India           15     32     34     36
# 297         297  197             India           15     32     34     36
# 298         298  198             India           15     32     34     36
# 299         299  199             India           15     32     34     36
#
#     Size4 Occassion
# 0      38   Festive
# 1      38   Festive
# 2      38   Festive
# ...

# %%
K1=pd.read_csv('Kids_1.csv')

# %%
K1
# Out:
#     Unnamed: 0       Brand Category Product_type  \
# 0            0  Pantaloons     KIDS      Dresses
# 1            1  Pantaloons     KIDS      Dresses
# 2            2  Pantaloons     KIDS      Dresses
# 3            3  Pantaloons     KIDS      Dresses
# 4            4  Pantaloons     KIDS      Dresses
# ..         ...         ...      ...          ...
# 95          95  Pantaloons     KIDS      Dresses
# 96          96  Pantaloons     KIDS      Dresses
# 97          97  Pantaloons     KIDS      Dresses
# 98          98  Pantaloons     KIDS      Dresses
# 99          99  Pantaloons     KIDS      Dresses
#
#                                          Product_Name  Product_code     Price
# 0   Medium Blue Printed Rayon Shirt Collar Girls F...           NaN    ₹ 1749
# 1   White Printed Rayon Round Neck Girls Flared Dr...           NaN  --------
# 2   Pink Embroidered Cotton Round Neck Girls Flare...           NaN    ₹ 1749
# ...

# %%
K2=pd.read_csv('Kids_2.csv')

# %%
K2
# Out:
#     Unnamed: 0 Wear_type Material_type                     Reviews  \
# 0            0   Dresses         Rayon   Be the first one to rate!
# 1            1   Dresses         Rayon   Be the first one to rate!
# 2            2   Dresses        Cotton   Be the first one to rate!
# 3            3   Dresses        Cotton   Be the first one to rate!
# 4            4   Dresses        Cotton   Be the first one to rate!
# ..         ...       ...           ...                         ...
# 95          95   Dresses        Cotton   Be the first one to rate!
# 96          96   Dresses        Cotton   Be the first one to rate!
# 97          97   Dresses        Cotton   Be the first one to rate!
# 98          98   Dresses        Cotton   Be the first one to rate!
# 99          99   Dresses        Cotton   Be the first one to rate!
#
#          color1  color2
# 0   Medium Blue     NaN
# 1         White     NaN
# 2          Pink     NaN
# 3          Aqua     NaN
# 4          Navy     NaN
# ...

# %%
K3=pd.read_csv('Kids_3.csv')

# %%
K3
# Out:
#     Unnamed: 0 Country_of_origin  Return_time  Size1  Size2   Size3    Size4  \
# 0            0             India           30   2-3Y   3-4Y    4-5Y     5-6Y
# 1            1             India           30   8-9Y  9-10Y  11-12Y   13-14Y
# 2            2             India           30   2-3Y   3-4Y    4-5Y     5-6Y
# 3            3             India           30   1-2Y   2-3Y    3-4Y     4-5Y
# 4            4             India           30   2-3Y   3-4Y    4-5Y     5-6Y
# ..         ...               ...          ...    ...    ...     ...      ...
# 95          95             India           30  3-6 M  6-9 M  9-12 M  12-18 M
# 96          96             India           30  3-6 M  6-9 M  9-12 M  12-18 M
# 97          97             India           30  3-6 M  6-9 M  9-12 M  12-18 M
# 98          98             India           30  3-6 M  6-9 M  9-12 M  12-18 M
# 99          99             India           30  3-6 M  6-9 M  9-12 M  12-18 M
#
#        Occassion
# 0   Western wear
# ...

# %%
K4=pd.read_csv('Kids_B1.csv')

# %%
K4
# Out:
#     Unnamed: 0  Sno           Brand  Category  Product_type  \
# 0            0    0          Intune      Boys       T-Shirt
# 1            1    1          Intune      Boys       T-Shirt
# 2            2    2          Intune      Boys       T-Shirt
# 3            3    3          Intune      Boys       T-Shirt
# 4            4    4            Life      Boys   T-Shirt Fit
# 5            5    5          Infuse      Boys       T-Shirt
# 6            6    6            Stop      Boys       T-Shirt
# 7            7    7            Life      Boys       T-Shirt
# 8            8    8           Pipin      Boys       T-Shirt
# 9            9    9          Intune      Boys       T-Shirt
# 10          10   10           Pipin      Boys       T-Shirt
# 11          11   11            Stop      Boys       T-Shirt
# 12          12   12            Stop      Boys       T-Shirt
# 13          13   13            Life      Boys       T-Shirt
# 14          14   14          Intune      Boys       T-Shirt
# ...

# %%
K5=pd.read_csv('Kids_B2.csv')

# %%
K5
# Out:
#     Unnamed: 0  Sno     Wear_type Material_type  \
# 0            0    0       T-Shirt   100% Cotton
# 1            1    1       T-Shirt   100% Cotton
# 2            2    2       T-Shirt   100% Cotton
# 3            3    3       T-Shirt   100% Cotton
# 4            4    4   T-Shirt Fit   100% Cotton
# 5            5    5       T-Shirt      Distress
# 6            6    6       T-Shirt      Polyster
# 7            7    7       T-Shirt      Polyster
# 8            8    8       T-Shirt      Polyster
# 9            9    9       T-Shirt     1 T-Shirt
# 10          10   10       T-Shirt      Polyster
# 11          11   11       T-Shirt      Polyster
# 12          12   12       T-Shirt     Dark Wash
# 13          13   13       T-Shirt      Polyster
# 14          14   14       T-Shirt   100% Cotton
# 15          15   15       T-Shirt   100% Cotton
# 16          16   16        Zipper      Mid Wash
# 17          17   17       T-Shirt      Polyster
# ...

# %%
K6=pd.read_csv('Kids_B3.csv')

# %%
K6
# Out:
#     Unnamed: 0  Sno Country_of_origin  Return_time        Size1    Size2  \
# 0            0    0             India         14.0        1-2 Y    2-3 Y
# 1            1    1             India         14.0        1-2 Y    2-3 Y
# 2            2    2             India         14.0        1-2 Y    2-3 Y
# 3            3    3             India         14.0        2-3 Y    3-4 Y
# 4            4    4             India         14.0      11-12 Y  13-14 Y
# 5            5    5             India          NaN      11-12 Y  13-14 Y
# 6            6    6                 1         14.0        2-3 Y    3-4 Y
# 7            7    7             India          NaN      11-12 Y  13-14 Y
# 8            8    8             India         14.0      11-12 Y    2-3 Y
# 9            9    9             India         14.0        2-3 Y    3-4 Y
# 10          10   10             India         14.0  10-11 YEARS  12-13 Y
# 11          11   11             India          NaN        2-3 Y    3-4 Y
# ...

# %%
Table_1=pd.concat([M1, W1, K1,K4], ignore_index=True)

# %%
Table_1.rename_axis('Sno',inplace=True, index=True)

# %%
Table_1.drop(columns=['Unnamed: 0','Sno'], axis=1, inplace=True)

# %%
Table_1
# Out:
#                     Brand Category  Product_type  \
# Sno
# 0    Vedant Fashions Ltd.      Men  Kurta Pajama
# 1    Vedant Fashions Ltd.      Men  Kurta Pajama
# 2    Vedant Fashions Ltd.      Men  Kurta Pajama
# 3    Vedant Fashions Ltd.      Men  Kurta Pajama
# 4    Vedant Fashions Ltd.      Men  Kurta Pajama
# ..                    ...      ...           ...
# 605                  Stop     Boys        Shorts
# 606                  Stop     Boys        Shorts
# 607                  Life     Boys        Shorts
# 608                  Stop     Boys       T-Shirt
# 609                Infuse     Boys        Shorts
#
#                                        Product_Name           Product_code  \
# Sno
# 0                     Rust Orange Printed Kurta Set            SOSK630-332
# 1    Flamingo Pink Chikankari Embroidered Kurta Set            SDES820-325
# 2          Teal Blue Chikankari Patterned Kurta Set            SDES820-326
# ...

# %%
Table_2=pd.concat([M2, W2, K2,K5], ignore_index=True)

# %%
Table_2.rename_axis('Sno',inplace=True, index=True)

# %%
Table_2.drop(columns=['Unnamed: 0','Sno'], axis=1, inplace=True)

# %%
Table_2
# Out:
#         Wear_type Material_type  \
# Sno
# 0    Kurta Pajama      --------
# 1    Kurta Pajama      --------
# 2    Kurta Pajama           NaN
# 3    Kurta Pajama           NaN
# 4    Kurta Pajama           NaN
# ..            ...           ...
# 605       T-Shirt         Nylon
# 606        Shorts        Cotton
# 607       T-Shirt         Nylon
# 608       T-Shirt         Nylon
# 609        Shorts      Distress
#
#                                                Reviews    color1    color2
# Sno
# 0          674 people have viewed the product recently  --------  --------
# 1          674 people have viewed the product recently  --------       NaN
# 2          674 people have viewed the product recently       NaN       NaN
# 3                                             --------       NaN       NaN
# 4          674 people have viewed the product recently       NaN  --------
# ..                                                 ...       ...       ...
# ...

# %%
Table_3=pd.concat([M3, W3, K3,K6], ignore_index=True)

# %%
Table_3.rename_axis('Sno',inplace=True, index=True)

# %%
Table_3.drop(columns=['Unnamed: 0','Sno'], axis=1, inplace=True)

# %%
Table_3
# Out:
#     Country_of_origin  Return_time    Size1    Size2    Size3   Size4  \
# Sno
# 0               India         15.0        S        M        L      XL
# 1               India         15.0        S        M        L      XL
# 2               India         15.0        S        M        L      XL
# 3            --------          NaN        S        M        L      XL
# 4               India         15.0        S        M        L      XL
# ..                ...          ...      ...      ...      ...     ...
# 605             India         14.0    2-3 Y    3-4 Y    5-6 Y   7-8 Y
# 606             India          NaN    2-3 Y    3-4 Y    5-6 Y   7-8 Y
# 607             India          NaN  11-12 Y  13-14 Y  15-16 Y  9-10 Y
# 608             India          NaN    2-3 Y    3-4 Y    5-6 Y   7-8 Y
# 609             India          NaN    2-3 Y    3-4 Y    5-6 Y   7-8 Y
#
#         Occassion
# Sno
# 0    Indo Western
# 1    Indo Western
# 2    Indo Western
# 3    Indo Western
# ...

# %%
Table_1.to_csv('Table_1.csv', index=True)

# %%
Table_2.to_csv('Table_2.csv', index=True)

# %%
Table_3.to_csv('Table_3.csv', index=True)

# %%
clothing_b = pd.concat([Table_1, Table_2, Table_3], axis=1)

# %%
clothing_b
# Out:
#                     Brand Category  Product_type  \
# Sno
# 0    Vedant Fashions Ltd.      Men  Kurta Pajama
# 1    Vedant Fashions Ltd.      Men  Kurta Pajama
# 2    Vedant Fashions Ltd.      Men  Kurta Pajama
# 3    Vedant Fashions Ltd.      Men  Kurta Pajama
# 4    Vedant Fashions Ltd.      Men  Kurta Pajama
# ..                    ...      ...           ...
# 605                  Stop     Boys        Shorts
# 606                  Stop     Boys        Shorts
# 607                  Life     Boys        Shorts
# 608                  Stop     Boys       T-Shirt
# 609                Infuse     Boys        Shorts
#
#                                        Product_Name           Product_code  \
# Sno
# 0                     Rust Orange Printed Kurta Set            SOSK630-332
# 1    Flamingo Pink Chikankari Embroidered Kurta Set            SDES820-325
# 2          Teal Blue Chikankari Patterned Kurta Set            SDES820-326
# ...

# %%
clothing_b.to_csv('clothing_b.csv', index=True)
